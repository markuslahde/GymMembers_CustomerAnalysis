# %%
# %run _args.py
# %run _io_functions.py
# %run _visualization_functions.py
# %run _stats_functions.py

# %%
args = parse_args()

# %%
df, _ = csv_to_df_loader(args.data_dir, args.production_data)

# %%
df.head()
# Out:
#    age  gender  session_duration_hours workout_type  \
# 0   56    Male                    1.69         Yoga
# 1   46  Female                    1.30         HIIT
# 2   32  Female                    1.11       Cardio
# 3   25    Male                    0.59     Strength
# 4   38    Male                    0.64     Strength
#
#    workout_frequency_days_per_week  experience_level fat_percentage_encoded  \
# 0                                4                 3                healthy
# 1                                4                 2                healthy
# 2                                4                 2                healthy
# 3                                3                 1                  obese
# 4                                3                 1                  obese
#
#    bmi_encoded experience_level_encoded age_encoded  \
# 0      obesity                   expert       50-59
# 1      obesity                  regular       40-49
# ...

# %% [markdown]
# ### GROUP 1

# %%
df_obesity_morbid_obesity = df.loc[((df['bmi_encoded'] == "obesity")|(df['bmi_encoded'] == "morbid_obesity"))]

# %%
pie_chart_categorical_df(df_obesity_morbid_obesity['gender'].to_frame())

# %%
pie_chart_categorical_df(df_obesity_morbid_obesity['experience_level_encoded'].to_frame())

# %%
pie_chart_categorical_df(df_obesity_morbid_obesity['workout_type'].to_frame())

# %%
histogram_categorical_df(df_obesity_morbid_obesity['workout_frequency_days_per_week'].to_frame())
# Out:
# /home/markuslahde/ETL/GymMembersExcercise/GymMembers_CustomerAnalysis/_visualization_functions.py:156: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   count = int(p.get_height())

# %%
histogram_numerical_df(df_obesity_morbid_obesity['age'].to_frame())

# %% [markdown]
# ### GROUP 3

# %%
df_underweight_or_underfat = df.loc[((df['fat_percentage_encoded'] == "underfat")|(df['bmi_encoded'] == "underweight"))]

# %%
pie_chart_categorical_df(df_underweight_or_underfat['gender'].to_frame())

# %%
pie_chart_categorical_df(df_underweight_or_underfat['experience_level_encoded'].to_frame())

# %%
pie_chart_categorical_df(df_underweight_or_underfat['workout_type'].to_frame())

# %%
histogram_categorical_df(df_underweight_or_underfat['workout_frequency_days_per_week'].to_frame())
# Out:
# /home/markuslahde/ETL/GymMembersExcercise/GymMembers_CustomerAnalysis/_visualization_functions.py:156: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   count = int(p.get_height())

# %%
histogram_numerical_df(df_underweight_or_underfat['age'].to_frame())

# %% [markdown]
# ### GROUP 2

# %%
df_no_obesity_morbid_obesity_underweight_or_underfat = df.loc[((df['bmi_encoded'] != "obesity")&(df['bmi_encoded'] != "morbid_obesity")&(df['bmi_encoded'] != "underweight")&(df['fat_percentage_encoded'] != "underfat"))]

# %%
pie_chart_categorical_df(df_no_obesity_morbid_obesity_underweight_or_underfat['gender'].to_frame())

# %%
pie_chart_categorical_df(df_no_obesity_morbid_obesity_underweight_or_underfat['experience_level_encoded'].to_frame())

# %%
pie_chart_categorical_df(df_no_obesity_morbid_obesity_underweight_or_underfat['workout_type'].to_frame())

# %%
histogram_numerical_df(df_no_obesity_morbid_obesity_underweight_or_underfat['age'].to_frame())

# %%
histogram_categorical_df(df_no_obesity_morbid_obesity_underweight_or_underfat['workout_frequency_days_per_week'].to_frame())
# Out:
# /home/markuslahde/ETL/GymMembersExcercise/GymMembers_CustomerAnalysis/_visualization_functions.py:156: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   count = int(p.get_height())

# %% [markdown]
# ### AVERAGES

# %%
histogram_numerical_df(df['hours_spent_at_gym_weekly'].to_frame(), bins="auto")

# %%
pie_chart_categorical_df(df['gender'].to_frame())

# %%
pie_chart_categorical_df(df['experience_level_encoded'].to_frame())

# %%
pie_chart_categorical_df(df['workout_type'].to_frame())

# %%
histogram_categorical_df(df['workout_frequency_days_per_week'].to_frame())
# Out:
# /home/markuslahde/ETL/GymMembersExcercise/GymMembers_CustomerAnalysis/_visualization_functions.py:152: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=rotation, ha='center', fontsize=12) # , ha='right'

# %%
histogram_numerical_df_quartiles(df['age'].to_frame())
